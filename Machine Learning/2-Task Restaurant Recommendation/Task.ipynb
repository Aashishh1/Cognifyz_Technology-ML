# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import jaccard_score
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv(r'C:\Users\Ashish Mishra\OneDrive\Desktop\Machine Learning\Dataset.csv')
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
dfRS = df[['Restaurant ID', 'Restaurant Name', 'Cuisines', 'Aggregate rating', 'Votes']]
dfRS.head()
# Out:
#    Restaurant ID         Restaurant Name                          Cuisines  \
# 0        6317637        Le Petit Souffle        French, Japanese, Desserts
# 1        6304287        Izakaya Kikufuji                          Japanese
# 2        6300002  Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3        6318506                    Ooma                   Japanese, Sushi
# 4        6314302             Sambo Kojin                  Japanese, Korean
#
#    Aggregate rating  Votes
# 0               4.8    314
# 1               4.5    591
# 2               4.4    270
# 3               4.9    365
# 4               4.8    229

# %% [markdown]
# ### Exploring and Cleaning the Dataset

# %%
def data_description():
    """Function to get details about each column."""
    details = []
    for col in dfRS.columns:
        details.append([
            col,
            dfRS[col].dtype,
            dfRS[col].isna().sum(),
            round(dfRS[col].isna().sum() / len(dfRS) * 100, 2),
            dfRS[col].nunique(),
            list(dfRS[col].drop_duplicates().sample(2).values)
        ])
    return pd.DataFrame(details, columns=['Column', 'Data Type', 'Missing Value', 'Pct Missing', 'Unique Count', 'Sample Values'])

data_description()
# Out:
#              Column Data Type  Missing Value  Pct Missing  Unique Count  \
# 0     Restaurant ID     int64              0         0.00          9551
# 1   Restaurant Name    object              0         0.00          7446
# 2          Cuisines    object              9         0.09          1825
# 3  Aggregate rating   float64              0         0.00            33
# 4             Votes     int64              0         0.00          1012
#
#                                        Sample Values
# 0                                   [18486847, 3182]
# 1  [Mustake Multicuisine Restaurant, Aggarwal Bik...
# 2  [European, North Indian, Continental, Italian,...
# 3                                         [3.2, 3.9]
# 4                                        [510, 1351]

# %%
dfRS = dfRS.dropna()
dfRS.head()
# Out:
#    Restaurant ID         Restaurant Name                          Cuisines  \
# 0        6317637        Le Petit Souffle        French, Japanese, Desserts
# 1        6304287        Izakaya Kikufuji                          Japanese
# 2        6300002  Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3        6318506                    Ooma                   Japanese, Sushi
# 4        6314302             Sambo Kojin                  Japanese, Korean
#
#    Aggregate rating  Votes
# 0               4.8    314
# 1               4.5    591
# 2               4.4    270
# 3               4.9    365
# 4               4.8    229

# %%
dfRS.rename(columns={
    'Restaurant ID': 'restaurant_id',
    'Restaurant Name': 'restaurant_name',
    'Cuisines': 'cuisines',
    'Aggregate rating': 'aggregate_rating',
    'Votes': 'votes'
}, inplace=True)

# %%
dfRS.duplicated().sum()
# Out:
# 0

# %%
dfRS['restaurant_name'].duplicated().sum()
# Out:
# 2105

# %%
dfRS = dfRS.sort_values(by=['restaurant_name', 'aggregate_rating'], ascending=False)
dfRS = dfRS.drop_duplicates('restaurant_name', keep='first')
dfRS.head()
# Out:
#       restaurant_id       restaurant_name  \
# 9523        6000871     �ukura��a Sofras۱
# 3120       18222559  {Niche} - Cafe & Bar
# 9334        7100938              wagamama
# 9454        6401789                tashas
# 4659       18361747    t Lounge by Dilmah
#
#                                          cuisines  aggregate_rating  votes
# 9523                                Kebab, Izgara               4.4    296
# 3120  North Indian, Chinese, Italian, Continental               4.1    492
# 9334                              Japanese, Asian               3.7    131
# 9454                          Cafe, Mediterranean               4.1    374
# 4659                          Cafe, Tea, Desserts               3.6     34

# %%
dfRS = dfRS[dfRS['aggregate_rating'] >= 4.0]
dfRS.head()
# Out:
#       restaurant_id       restaurant_name  \
# 9523        6000871     �ukura��a Sofras۱
# 3120       18222559  {Niche} - Cafe & Bar
# 9454        6401789                tashas
# 9385        6113857        sketch Gallery
# 1837       18418247            feel ALIVE
#
#                                          cuisines  aggregate_rating  votes
# 9523                                Kebab, Izgara               4.4    296
# 3120  North Indian, Chinese, Italian, Continental               4.1    492
# 9454                          Cafe, Mediterranean               4.1    374
# 9385                        British, Contemporary               4.5    148
# 1837       North Indian, American, Asian, Biryani               4.7     69

# %%
xTabRestoCuisines = pd.crosstab(dfRS['restaurant_name'], dfRS['cuisines'])
xTabRestoCuisines.head()
# Out:
# cuisines                 African  African, Portuguese  American  \
# restaurant_name
# 'Ohana                         0                    0         0
# 10 Downing Street              0                    0         0
# 11th Avenue Cafe Bistro        0                    0         0
# 145 Kala Ghoda                 0                    0         0
# 19 Flavours Biryani            0                    0         0
#
# cuisines                 American, Asian, Burger  \
# restaurant_name
# 'Ohana                                         0
# 10 Downing Street                              0
# 11th Avenue Cafe Bistro                        0
# 145 Kala Ghoda                                 0
# 19 Flavours Biryani                            0
#
# cuisines                 American, Asian, European, Seafood  \
# restaurant_name
# 'Ohana                                                    0
# 10 Downing Street                                         0
# 11th Avenue Cafe Bistro                                   0
# 145 Kala Ghoda                                            0
# 19 Flavours Biryani                                       0
#
# cuisines                 American, Asian, Italian, Seafood  American, BBQ  \
# restaurant_name
# 'Ohana                                                   0              0
# 10 Downing Street                                        0              0
# 11th Avenue Cafe Bistro                                  0              0
# 145 Kala Ghoda                                           0              0
# 19 Flavours Biryani                                      0              0
#
# cuisines                 American, BBQ, Burger  American, BBQ, Sandwich  \
# restaurant_name
# 'Ohana                                       0                        0
# 10 Downing Street                            0                        0
# 11th Avenue Cafe Bistro                      0                        0
# 145 Kala Ghoda                               0                        0
# 19 Flavours Biryani                          0                        0
#
# cuisines                 American, BBQ, Southern  ...  Turkish  Turkish Pizza  \
# restaurant_name                                   ...
# 'Ohana                                         0  ...        0              0
# 10 Downing Street                              0  ...        0              0
# 11th Avenue Cafe Bistro                        0  ...        0              0
# 145 Kala Ghoda                                 0  ...        0              0
# 19 Flavours Biryani                            0  ...        0              0
#
# cuisines                 Turkish, Arabian, Middle Eastern  \
# restaurant_name
# 'Ohana                                                  0
# 10 Downing Street                                       0
# 11th Avenue Cafe Bistro                                 0
# 145 Kala Ghoda                                          0
# 19 Flavours Biryani                                     0
#
# cuisines                 Turkish, Mediterranean, Middle Eastern  Vietnamese  \
# restaurant_name
# 'Ohana                                                        0           0
# 10 Downing Street                                             0           0
# 11th Avenue Cafe Bistro                                       0           0
# 145 Kala Ghoda                                                0           0
# 19 Flavours Biryani                                           0           0
#
# cuisines                 Vietnamese, Fish and Chips  Western, Asian, Cafe  \
# restaurant_name
# 'Ohana                                            0                     0
# 10 Downing Street                                 0                     0
# 11th Avenue Cafe Bistro                           0                     0
# 145 Kala Ghoda                                    0                     0
# 19 Flavours Biryani                               0                     0
#
# cuisines                 World Cuisine  World Cuisine, Mexican, Italian  \
# restaurant_name
# 'Ohana                               0                                0
# 10 Downing Street                    0                                0
# 11th Avenue Cafe Bistro              0                                0
# 145 Kala Ghoda                       0                                0
# 19 Flavours Biryani                  0                                0
#
# cuisines                 World Cuisine, Patisserie, Cafe
# restaurant_name
# 'Ohana                                                 0
# 10 Downing Street                                      0
# 11th Avenue Cafe Bistro                                0
# 145 Kala Ghoda                                         0
# 19 Flavours Biryani                                    0
#
# [5 rows x 753 columns]

# %%
jaccardDist = pdist(xTabRestoCuisines.values, metric='jaccard')

# %%
jaccardMatrix = squareform(jaccardDist)
jaccardSim = 1 - jaccardMatrix

# %%
dfJaccard = pd.DataFrame(
    jaccardSim,
    index=xTabRestoCuisines.index,
    columns=xTabRestoCuisines.index
)

dfJaccard.head()
# Out:
# restaurant_name          'Ohana  10 Downing Street  11th Avenue Cafe Bistro  \
# restaurant_name
# 'Ohana                      1.0                0.0                      0.0
# 10 Downing Street           0.0                1.0                      0.0
# 11th Avenue Cafe Bistro     0.0                0.0                      1.0
# 145 Kala Ghoda              0.0                0.0                      0.0
# 19 Flavours Biryani         0.0                0.0                      0.0
#
# restaurant_name          145 Kala Ghoda  19 Flavours Biryani  \
# restaurant_name
# 'Ohana                              0.0                  0.0
# 10 Downing Street                   0.0                  0.0
# 11th Avenue Cafe Bistro             0.0                  0.0
# 145 Kala Ghoda                      1.0                  0.0
# 19 Flavours Biryani                 0.0                  1.0
#
# restaurant_name          1918 Bistro & Grill  2 Dog  22nd Parallel  \
# restaurant_name
# 'Ohana                                   0.0    0.0            0.0
# 10 Downing Street                        0.0    0.0            0.0
# 11th Avenue Cafe Bistro                  0.0    0.0            0.0
# 145 Kala Ghoda                           0.0    0.0            0.0
# 19 Flavours Biryani                      0.0    0.0            0.0
#
# restaurant_name          3 Wise Monkeys  38 Barracks  ...  Zoeys Pizzeria  \
# restaurant_name                                       ...
# 'Ohana                              0.0          0.0  ...             0.0
# 10 Downing Street                   0.0          0.0  ...             0.0
# 11th Avenue Cafe Bistro             0.0          0.0  ...             0.0
# 145 Kala Ghoda                      0.0          0.0  ...             0.0
# 19 Flavours Biryani                 0.0          0.0  ...             0.0
#
# restaurant_name          Zolocrust - Hotel Clarks Amer  \
# restaurant_name
# 'Ohana                                             0.0
# 10 Downing Street                                  0.0
# 11th Avenue Cafe Bistro                            0.0
# 145 Kala Ghoda                                     0.0
# 19 Flavours Biryani                                0.0
#
# restaurant_name          Zombie Burger + Drink Lab  Zuka Choco-la  Zunzi's  \
# restaurant_name
# 'Ohana                                         0.0            0.0      0.0
# 10 Downing Street                              0.0            0.0      0.0
# 11th Avenue Cafe Bistro                        0.0            0.0      0.0
# 145 Kala Ghoda                                 0.0            0.0      0.0
# 19 Flavours Biryani                            0.0            0.0      0.0
#
# restaurant_name          feel ALIVE  sketch Gallery  tashas  \
# restaurant_name
# 'Ohana                          0.0             0.0     0.0
# 10 Downing Street               0.0             0.0     0.0
# 11th Avenue Cafe Bistro         0.0             0.0     0.0
# 145 Kala Ghoda                  0.0             0.0     0.0
# 19 Flavours Biryani             0.0             0.0     0.0
#
# restaurant_name          {Niche} - Cafe & Bar  �ukura��a Sofras۱
# restaurant_name
# 'Ohana                                    0.0                0.0
# 10 Downing Street                         0.0                0.0
# 11th Avenue Cafe Bistro                   0.0                0.0
# 145 Kala Ghoda                            0.0                0.0
# 19 Flavours Biryani                       0.0                0.0
#
# [5 rows x 1236 columns]

# %%
input_restaurant = 'Ooma'

# %%
sim = dfJaccard.loc[input_restaurant].sort_values(ascending=False)
sim = pd.DataFrame({'restaurant_name': sim.index, 'simScore': sim.values})
sim = sim[(sim['restaurant_name'] != input_restaurant) & (sim['simScore'] >= 0.7)].head(5)
recommendations = pd.merge(
    sim,
    dfRS[['restaurant_name', 'aggregate_rating']],
    how='inner',
    on='restaurant_name'
)

# %%
recommendations = recommendations.sort_values('aggregate_rating', ascending=False).drop_duplicates('restaurant_name', keep='first')
recommendations
# Out:
#   restaurant_name  simScore  aggregate_rating
# 2            Nobu       1.0               4.4
# 3           Nagai       1.0               4.3
# 4         Ichiban       1.0               4.3
# 1           Osaka       1.0               4.2
# 0           Guppy       1.0               4.1

# %% [markdown]
# ### Conclusion:
# The above data will show up to the top 5 recommended restaurants with the best ratings. The ratings are curated to include only restaurants with an aggregate rating of 4 and above. This ensures that the recommendation system provides high-quality suggestions objectively.
# ```
